# %% [markdown]
# # 5.2 Code Brief: Hands-On Vibecoding
#
# Condensed reference for notebook 5.2.

# %% [markdown]
# ## Effective Prompt Template
#
# ```
# Using Python with scikit-learn:
# 1. Load data from [path]
# 2. Create target: [definition]
# 3. Use features: [list]
# 4. Build: [model with params]
# 5. Evaluate: [metrics]
# 6. Visualize: [chart type]
# ```
