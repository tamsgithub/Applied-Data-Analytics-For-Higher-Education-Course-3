# %% [markdown]
# # 1.1 Code Brief: AI-Assisted Coding in Google Colab with Gemini
#
# Condensed reference for using Gemini in Colab.

# %% [markdown]
# ## Quick Setup
#
# ```python
# # Upload data
# from google.colab import files
# uploaded = files.upload()
#
# # OR mount Google Drive
# from google.colab import drive
# drive.mount('/content/drive')
# ```
#
# ## Using Gemini
#
# | Method | How |
# |:-------|:----|
# | **Chat panel** | Click ✨ icon → type request → insert generated cell |
# | **Inline autocomplete** | Type a comment → Gemini suggests code below |
# | **Explain code** | Select cell → right-click → "Explain this code" |
# | **Fix errors** | Click "Fix with Gemini" on error output |
#
# ## CRISP Framework (same as Codex)
#
# ```
# C — Context:      "I have training.csv uploaded to Colab..."
# R — Role:         "Help me as an IR analyst..."
# I — Instructions: "Build a Random Forest to predict DEPARTED..."
# S — Specifics:    "200 trees, max_depth=12, StandardScaler..."
# P — Product:      "Classification report, ROC curve, feature importance chart"
# ```
#
# ## Colab Tips
#
# ```python
# # Free GPU: Runtime → Change runtime type → T4 GPU
# # Install packages (reset each session):
# !pip install xgboost shap
#
# # Secrets (API keys):
# from google.colab import userdata
# key = userdata.get('MY_API_KEY')
# ```
