# %% [markdown]
# # 2.3 Code Brief: Tuning Tree-Based Models
#
# This notebook contains a condensed reference of the key code patterns from notebook 2.3. Use it as a quick reference.

# %% [markdown]
# ## Key Pattern: Instantiate → Fit → Predict
#
# ```python
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.ensemble import RandomForestClassifier
# from xgboost import XGBClassifier
#
# # Same three lines for any model:
# model = ModelClass(**params)
# model.fit(X_train, y_train)
# y_prob = model.predict_proba(X_test)[:, 1]
# ```
